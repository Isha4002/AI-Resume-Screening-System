# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

print("AI Resume Screener Started 🚀")
# Out:
# AI Resume Screener Started 🚀

# %%
resume = """
Python
Machine Learning
Data Analysis
Pandas
NumPy
Scikit-Learn
"""

job_description = """
Looking for a Machine Learning Intern.

Required Skills:
Python
Machine Learning
Pandas
Scikit-Learn
Deep Learning
"""

# %%
vectorizer = TfidfVectorizer()

vectors = vectorizer.fit_transform(
    [resume, job_description]
)

print("Vectorization Complete")
# Out:
# Vectorization Complete

# %%
score = cosine_similarity(
    vectors[0:1],
    vectors[1:2]
)

print(
    "Resume Match Score:",
    round(score[0][0] * 100, 2),
    "%"
)
# Out:
# Resume Match Score: 48.52 %

# %%
resume_skills = set(resume.lower().split())
job_skills = set(job_description.lower().split())

missing_skills = job_skills - resume_skills

print("Missing Skills:")
print(missing_skills)
# Out:
# Missing Skills:
# {'deep', 'skills:', 'for', 'intern.', 'required', 'a', 'looking'}

# %%
if score[0][0] >= 0.7:
    print("✅ Strong Match")
elif score[0][0] >= 0.5:
    print("⚠️ Moderate Match")
else:
    print("❌ Weak Match")
# Out:
# ❌ Weak Match

# %%
skills_database = [
    "python",
    "machine learning",
    "deep learning",
    "pandas",
    "numpy",
    "scikit-learn",
    "tensorflow",
    "sql",
    "java",
    "data analysis"
]

# %%
def extract_skills(text):
    text = text.lower()

    found_skills = []

    for skill in skills_database:
        if skill in text:
            found_skills.append(skill)

    return found_skills

# %%
resume_found = extract_skills(resume)
job_found = extract_skills(job_description)

print("Resume Skills:")
print(resume_found)

print("\nJob Skills:")
print(job_found)
# Out:
# Resume Skills:
# ['python', 'machine learning', 'pandas', 'numpy', 'scikit-learn', 'data analysis']
#
# Job Skills:
# ['python', 'machine learning', 'deep learning', 'pandas', 'scikit-learn']

# %%
missing = set(job_found) - set(resume_found)

print("Missing Skills:")
print(missing)
# Out:
# Missing Skills:
# {'deep learning'}

# %%
import streamlit as st

print("Streamlit Ready")
# Out:
# Streamlit Ready

# %%
app_code = '''
import streamlit as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

st.title("AI Resume Screener")

resume = st.text_area("Paste Resume")

job_description = st.text_area("Paste Job Description")

if st.button("Analyze"):

    vectorizer = TfidfVectorizer()

    vectors = vectorizer.fit_transform(
        [resume, job_description]
    )

    score = cosine_similarity(
        vectors[0:1],
        vectors[1:2]
    )

    st.success(
        f"Match Score: {round(score[0][0]*100,2)}%"
    )
'''

with open("app.py", "w") as f:
    f.write(app_code)

print("app.py created successfully")
# Out:
# app.py created successfully
